# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import seaborn as sns
import hvplot.pandas

from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
uscities = pd.read_csv("../data/uscities.csv")
uscities_df = pd.DataFrame(uscities)
uscities_df.head()
# Out:
#           city   city_ascii state_id  state_name  county_fips  county_name  \
# 0     New York     New York       NY    New York        36081       Queens
# 1  Los Angeles  Los Angeles       CA  California         6037  Los Angeles
# 2      Chicago      Chicago       IL    Illinois        17031         Cook
# 3        Miami        Miami       FL     Florida        12086   Miami-Dade
# 4       Dallas       Dallas       TX       Texas        48113       Dallas
#
#        lat       lng  population  density source  military  incorporated  \
# 0  40.6943  -73.9249    18972871  10768.2  shape     False          True
# 1  34.1141 -118.4068    12121244   3267.6  shape     False          True
# 2  41.8375  -87.6866     8595181   4576.6  shape     False          True
# 3  25.7840  -80.2101     5711945   4945.7  shape     False          True
# 4  32.7935  -96.7667     5668165   1522.2  shape     False          True
#
#               timezone  ranking  \
# 0     America/New_York        1
# ...

# %%
uscities_df.columns
# Out:
# Index(['city', 'city_ascii', 'state_id', 'state_name', 'county_fips',
#        'county_name', 'lat', 'lng', 'population', 'density', 'source',
#        'military', 'incorporated', 'timezone', 'ranking', 'zips', 'id'],
#       dtype='object')

# %%
filtered_uscities_df = uscities_df[['city', 'state_name', 'lat', 'lng', 'population', 'density']]
us_cities_df = pd.DataFrame(filtered_uscities_df)
us_cities_df.head()
# Out:
#           city  state_name      lat       lng  population  density
# 0     New York    New York  40.6943  -73.9249    18972871  10768.2
# 1  Los Angeles  California  34.1141 -118.4068    12121244   3267.6
# 2      Chicago    Illinois  41.8375  -87.6866     8595181   4576.6
# 3        Miami     Florida  25.7840  -80.2101     5711945   4945.7
# 4       Dallas       Texas  32.7935  -96.7667     5668165   1522.2

# %%
map_plot_1 = us_cities_df.hvplot.points("lng", "lat", geo = True, color = "city", alpha = 0.6, size = "density", tiles ='OSM')

# Display the map
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [lng,lat]   (city,density)
