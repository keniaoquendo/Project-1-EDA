# %%
#import pandas
import pandas as pd

# %%
#file path
file_path = "NH_CovidVaxAverages_20230917.csv"

# %%
#read in file using pandas
NH_vax_averages = pd.read_csv(file_path)

#display first 10 rows
NH_vax_averages.head(10)
# Out:
#   State  Percent of residents who are up-to-date on their vaccines  \
# 0    US                                               61.7
# 1    AK                                               73.2
# 2    AL                                               53.4
# 3    AR                                               61.6
# 4    AZ                                               43.4
# 5    CA                                               67.7
# 6    CO                                               67.7
# 7    CT                                               68.5
# 8    DC                                               74.2
# 9    DE                                               74.6
#
#    Percent of staff who are up-to-date on their vaccines  \
# 0                                               25.5
# 1                                               30.4
# 2                                               15.6
# 3                                               19.6
# 4                                               15.7
# 5                                               45.8
# 6                                               37.9
# 7                                               23.7
# 8                                               51.6
# 9                                               25.0
#
#   Date vaccination data last updated
# 0                         09/17/2023
# 1                         09/17/2023
# 2                         09/17/2023
# 3                         09/17/2023
# 4                         09/17/2023
# 5                         09/17/2023
# 6                         09/17/2023
# 7                         09/17/2023
# 8                         09/17/2023
# 9                         09/17/2023

# %%
#creates new dataframe without the staff column
NH_vax_averages_CLEAN = NH_vax_averages[["State", "Percent of residents who are up-to-date on their vaccines", "Date vaccination data last updated"]]

#display first 10 rows
NH_vax_averages_CLEAN.head(10)
# Out:
#   State  Percent of residents who are up-to-date on their vaccines  \
# 0    US                                               61.7
# 1    AK                                               73.2
# 2    AL                                               53.4
# 3    AR                                               61.6
# 4    AZ                                               43.4
# 5    CA                                               67.7
# 6    CO                                               67.7
# 7    CT                                               68.5
# 8    DC                                               74.2
# 9    DE                                               74.6
#
#   Date vaccination data last updated
# 0                         09/17/2023
# 1                         09/17/2023
# 2                         09/17/2023
# 3                         09/17/2023
# 4                         09/17/2023
# 5                         09/17/2023
# 6                         09/17/2023
# 7                         09/17/2023
# 8                         09/17/2023
# 9                         09/17/2023

# %%
NH_vax_averages_CLEAN.to_csv("CLEAN_NH_CovidVaxAverages_20230917.csv", index = False)
