# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
from scipy.stats import sem
import scipy.stats as stats
from scipy.stats import linregress

# %% [markdown]
# #### Cleaning code for CSV files

# %% [markdown]
# ##### Sally's cleaning

# %%
# # Sally
# # Read csv file
# cov19_vax_us_df = pd.read_csv('../data/covid19_vaccinations_in_us.csv')

# cov19_vax_us_df.head()

# cov19_vax_us_df.shape

# cov19_vax_us_df.duplicated().sum()

# cov19_vax_us_df["Jurisdiction (State/Territory) or Federal Entity"].unique()

# # only columns we want to analysize
# cols = ['Jurisdiction (State/Territory) or Federal Entity', 'Total doses distributed', 'Total doses administered by jurisdiction', 
#                                       'Residents with at least one dose', 'Percent of total pop with at least one dose', 
#                                       'Residents 18+ with a completed primary series',  
#                                       'Residents 65+ with at least one dose', 
#                                       'Residents 65+ with a completed primary series',  
#                                       'Residents 12+ with at least one dose',
#                                       'Residents 12+ with a completed primary series', 
#                                       'Residents 5+ with at least one dose',  
#                                       'Residents 5+ with a completed primary series',]

# col_cov19_vax_us_df = cov19_vax_us_df[cols]
# col_cov19_vax_us_df.head(50)

# col_cov19_vax_us_df = col_cov19_vax_us_df.set_index("Jurisdiction (State/Territory) or Federal Entity")

# col_cov19_vax_us_df = col_cov19_vax_us_df.rename(index = {"New York State": "New York"})

# col_cov19_vax_us_df.head()

# # drop rows that are not part of continental US, for states only

# col_cov19_vax_us_df = col_cov19_vax_us_df.drop(labels = ["United States", "District of Columbia",'American Samoa', 'Bureau of Prisons', 'Dept of Defense','Federated States of Micronesia',
#                                                          'Guam', 'Indian Health Svc', 'Marshall Islands', 'Northern Mariana Islands', 'Puerto Rico',
#                                                          'Republic of Palau', 'Veterans Health', 'Virgin Islands'])

# col_cov19_vax_us_df.shape

# col_cov19_vax_us_df.head(50)

# col_cov19_vax_us_df.reset_index(inplace=True)

# col_cov19_vax_us_df.head(50)

# col_cov19_vax_us_df = col_cov19_vax_us_df.rename(columns={"Jurisdiction (State/Territory) or Federal Entity": "State"})
# col_cov19_vax_us_df.head(50)

# col_cov19_vax_us_df.isnull().any()

# col_cov19_vax_us_df.to_csv("../data/5CLEAN_covid19_vaccinations_in_us.csv", index = False)

# %% [markdown]
# ##### Kenia's cleaning

# %%
# Kenia

# %% [markdown]
# ##### Gwen's cleaning

# %%
# Gwen

# %% [markdown]
# ##### Jackie's cleaning

# %%
# Jackie

# %% [markdown]
# ## Reading in multiple csv files to merge

# %%
# read cleaned us vax info
clean_vax_df= pd.read_csv ('../data/5CLEAN_covid19_vaccinations_in_us.csv')
clean_vax_df.head(52)
# Out:
#              State  Total doses distributed  \
# 0           Alaska                  2176065
# 1          Alabama                 12349530
# 2         Arkansas                  8373210
# 3          Arizona                 19959120
# 4       California                121107865
# 5         Colorado                 17769135
# 6      Connecticut                 11881825
# 7         Delaware                  3352025
# 8          Florida                 61526685
# 9          Georgia                 28727475
# 10          Hawaii                  4677910
# 11            Iowa                  9429185
# 12           Idaho                  4751720
# 13        Illinois                 38328915
# 14         Indiana                 18989660
# 15          Kansas                  8356725
# 16        Kentucky                 12200975
# 17       Louisiana                 10282120
# 23                              4236460
# 24                              1835283
# 25                               726052
# 26                              9392711
# 27                               524966
# 28                              1412159
# 29                              1194903
# 30                              8374653
# 31                              1973116
# 32                              2392442
# 33                             18297040
# 34                              7639577
# 35                              2950731
# 36                              3420770
# 37                             11562144
# 38                              1117840
# 39                              3646320
# 40                               739933
# 41                              4391102
# 42                             22160914
# 43                              2393586
# 44                              7712390
# 45                               614499
# 46                              6428635
# 47                              4341550
# 48                              1208323
# 49                               352361
#
#     Residents 5+ with a completed primary series
# 0                                         474707
# 1                                        2607644
# 2                                        1715538
# 3                                        4805903
# 4                                       29371810
# 5                                        4215139
# 6                                        2948721
# 7                                         713143
# 8                                       14946304
# 9                                        6085428
# 10                                       1150133
# 11                                       2024863
# 12                                       1008843
# 13                                       8988132
# 14                                       3886503
# 15                                       1898540
# 16                                       2661099
# 17                                       2558038
# 18                                       5770765
# 19                                       4794005
# 20                                       1116192
# 21                                       6221234
# 22                                       4039371
# 23                                       3615520
# 24                                       1598993
# 25                                        631474
# 26                                       6987602
# 27                                        446460
# 28                                       1278092
# 29                                        977652
# 30                                       7008596
# 31                                       1575380
# 32                                       1962621
# 33                                      15686124
# 34                                       7048249
# 35                                       2394480
# 36                                       3048791
# 37                                       9373738
# 38                                        926851
# 39                                       3081834
# 40                                        586667
# 41                                       3843432
# 42                                      18363854
# 43                                       2134792
# 44                                       6507230
# 45                                        531036
# 46                                       5755895
# 47                                       3954892
# 48                                       1069264
# 49                                        306932

# %%
# read cleaned us pop
clean_st_pop_df= pd.read_csv ('../data/CLEAN_regionpopulation.csv')
clean_st_pop_df.head(50)
# Out:
#              State  2022 Population Estimate     Region
# 0      Connecticut                   3626205  Northeast
# 1            Maine                   1385340  Northeast
# 2    Massachusetts                   6981974  Northeast
# 3    New Hampshire                   1395231  Northeast
# 4       New Jersey                   9261699  Northeast
# 5         New York                  19677151  Northeast
# 6     Pennsylvania                  12972008  Northeast
# 7     Rhode Island                   1093734  Northeast
# 8          Vermont                    647064  Northeast
# 9         Illinois                  12582032    Midwest
# 10         Indiana                   6833037    Midwest
# 11            Iowa                   3200517    Midwest
# 12        Michigan                  10034113    Midwest
# 13       Minnesota                   5717184    Midwest
# 14        Missouri                   6177957    Midwest
# 15            Ohio                  11756058    Midwest
# 16       Wisconsin                   5892539    Midwest
# 17         Alabama                   5074296      South
# 18        Arkansas                   3045637      South
# 19        Delaware                   1018396      South
# 20         Florida                  22244823      South
# 21         Georgia                  10912876      South
# 22          Kansas                   2937150      South
# 23        Kentucky                   4512310      South
# 24       Louisiana                   4590241      South
# 25        Maryland                   6164660      South
# 26     Mississippi                   2940057      South
# 27        Nebraska                   1967923      South
# 28  North Carolina                  10698973      South
# 29    North Dakota                    779261      South
# 30        Oklahoma                   4019800      South
# 31  South Carolina                   5282634      South
# 32    South Dakota                    909824      South
# 33       Tennessee                   7051339      South
# 34           Texas                  30029572      South
# 35        Virginia                   8683619      South
# 36   West Virginia                   1775156      South
# 37          Alaska                    733583       West
# 38         Arizona                   7359197       West
# 39      California                  39029342       West
# 34          49729.0      517794.0                        24089.0
# 35          18520.0      171792.0                         8103.0
# 36           9232.0      158968.0                         3707.0
# 37          53049.0      557522.0                        22981.0
# 38           4083.0       42462.0                         1764.0
# 39          20842.0      224379.0                         8778.0
# 40           3472.0       34467.0                         1592.0
# 41          30408.0      330056.0                        15597.0
# 42         104421.0      931558.0                        58265.0
# 43           5867.0       83772.0                         2808.0
# 44            976.0       23816.0                          321.0
# 45          23148.0      301033.0                         9805.0
# 46          15078.0      246807.0                         8830.0
# 47           8339.0       98692.0                         4281.0
# 48          17064.0      223540.0                         6022.0
# 49           1855.0       20597.0                          969.0

# %% [markdown]
# * Merge US population data with vaccination data

# %%
merge_vax_pop_df = pd.merge(clean_st_pop_df, clean_vax_df, on="State")
merge_vax_pop_df.head()
# Out:
#            State  2022 Population Estimate     Region  \
# 0    Connecticut                   3626205  Northeast
# 1          Maine                   1385340  Northeast
# 2  Massachusetts                   6981974  Northeast
# 3  New Hampshire                   1395231  Northeast
# 4     New Jersey                   9261699  Northeast
#
#    Total doses distributed  Total doses administered by jurisdiction  \
# 0                 11881825                                   9040989
# 1                  4981040                                   3542346
# 2                 23747420                                  18179748
# 3                  5121800                                   2983122
# 4                 29637655                                  19826065
#
#    Residents with at least one dose  \
# 0                           3670090
# 1                           1315892
# 2                           7393770
# 3                           1203845
# 4                           8430561
#
#    Percent of total pop with at least one dose  \
# 0                                         95.0
# 1                                         95.0
# 2                                         95.0
# 3                                         88.5
# 4                                         94.9
#
#    Residents 18+ with a completed primary series  \
# 0                                        2602449
# 1                                        1006201
# 2                                        5087207
# 3                                         891141
# 4                                        6195423
#
#    Residents 65+ with at least one dose  \
# 0                                823664
# 1                                366916
# 2                               1549552
# 3                                304648
# 4                               1686625
#
#    Residents 65+ with a completed primary series  \
# 0                                         654355
# 1                                         303658
# 2                                        1229041
# 3                                         257396
# 4                                        1439157
#
#    Residents 12+ with at least one dose  \
# 0                               3481915
# 1                               1252248
# 2                               6947787
# 3                               1152503
# 4                               8011957
#
#    Residents 12+ with a completed primary series  \
# 0                                        2816633
# 1                                        1070587
# 2                                        5480791
# 3                                         946332
# 4                                        6701732
#
#    Residents 5+ with at least one dose  \
# 0                              3640198
# 1                              1303033
# 2                              7306432
# 3                              1194903
# 4                              8374653
#
#    Residents 5+ with a completed primary series
# 0                                       2948721
# 1                                       1116192
# 2                                       5770765
# 3                                        977652
# 4                                       7008596

# %% [markdown]
# * Merge Population/Vaccination data with COVID-19 data

# %%
# merge with deaths csv
merge_all_df = pd.merge(merge_vax_pop_df, clean_cov_death_df, on = "State")
merge_all_df.head(50)
# Out:
#              State  2022 Population Estimate     Region  \
# 0      Connecticut                   3626205  Northeast
# 1            Maine                   1385340  Northeast
# 2    Massachusetts                   6981974  Northeast
# 3    New Hampshire                   1395231  Northeast
# 4       New Jersey                   9261699  Northeast
# 5         New York                  19677151  Northeast
# 6     Pennsylvania                  12972008  Northeast
# 7     Rhode Island                   1093734  Northeast
# 8          Vermont                    647064  Northeast
# 9         Illinois                  12582032    Midwest
# 13                                975356
# 14                               1058140
# 15                               1939194
# 16                               1081267
# 17                                840073
# 18                                524198
# 19                                225182
# 20                               4944364
# 21                               1494072
# 22                                513572
# 23                                750781
# 24                                687335
# 25                               1057586
# 26                                457131
# 27                                318755
# 28                               2366178
# 29                                127584
# 30                                715240
# 31                                994994
# 32                                197409
# 33                               1082135
# 34                               3756924
# 35                               1565047
# 36                                354072
# 37                                 90909
# 38                               1348446
# 39                               6058090
# 40                                902546
# 41                                281382
# 42                                287593
# 43                                205131
# 44                                518532
# 45                                466822
# 46                                786172
# 47                                388400
# 48                               1298687
# 49                                 97375
#
#     Residents 65+ with a completed primary series  ...  \
# 0                                          654355  ...
# 1                                          303658  ...
# 2                                         1229041  ...
# 3                                          257396  ...
# 4                                         1439157  ...
# 5                                         3195894  ...
# 6                                         2445124  ...
# 7                                          200777  ...
# 8                                          133976  ...
# 9                                         1865350  ...
# 10                                         976073  ...
# 11                                         532779  ...
# 12                                        1615024  ...
# 13                                         919278  ...
# 14                                         943084  ...
# 15                                        1834185  ...
# 16                                        1008957  ...
# 17                                         725159  ...
# 18                                         440981  ...
# 19                                         193640  ...
# 20                                        4244393  ...
# 21                                        1315992  ...
# 22                                         462691  ...
# 23                                         671775  ...
# 24                                         647350  ...
# 25                                         954352  ...
# 26                                         419847  ...
# 27                                         297818  ...
# 28                                        1811611  ...
# 29                                         110011  ...
# 30                                         594390  ...
# 31                                         860836  ...
# 32                                         159605  ...
# 33                                         992506  ...
# 34                                        3330121  ...
# 35                                        1329147  ...
# 36                                         321971  ...
# 37                                          81999  ...
# 38                                        1188267  ...
# 39                                        5441414  ...
# 40                                         818078  ...
# 41                                         258069  ...
# 42                                         263280  ...
# 43                                         184619  ...
# 44                                         442765  ...
# 45                                         381631  ...
# 46                                         723687  ...
# 47                                         354415  ...
# 48                                        1188410  ...
# 49                                          87140  ...
#
#     Residents 5+ with at least one dose  \
# 0                               3640198
# 1                               1303033
# 2                               7306432
# 3                               1194903
# 4                               8374653
# 5                              18297040
# 6                              11562144
# 7                               1117840
# 8                                614499
# 9                               9928857
# 10                              4321434
# 11                              2215662
# 12                              6921128
# 13                              4390824
# 14                              4236460
# 15                              7639577
# 16                              4341550
# 17                              3183544
# 18                              2104099
# 19                               856096
# 20                             17757764
# 21                              7248684
# 22                              2209027
# 23                              3069983
# 24                              2915981
# 25                              5500247
# 26                              1835283
# 27                              1412159
# 28                              9392711
# 29                               524966
# 30                              2950731
# 31                              3646320
# 32                               739933
# 33                              4391102
# 34                             22160914
# 35                              7712390
# 36                              1208323
# 37                               530318
# 38                              5663049
# 39                             33267856
# 40                              4776300
# 41                              1285596
# 42                              1139488
# 43                               726052
# 44                              2392442
# 45                              1973116
# 46                              3420770
# 47                              2393586
# 48                              6428635
# 49                               352361
#
#     Residents 5+ with a completed primary series  Data As Of  Start Date  \
# 0                                        2948721  09/27/2023  01/01/2020
# 1                                        1116192  09/27/2023  01/01/2020
# 2                                        5770765  09/27/2023  01/01/2020
# 3                                         977652  09/27/2023  01/01/2020
# Utah            01/01/2020  09/23/2023  All Sexes  All Ages          5867.0
# Washington      01/01/2020  09/23/2023  All Sexes  All Ages         15078.0
# Wyoming         01/01/2020  09/23/2023  All Sexes  All Ages          1855.0
#
#                 Total Deaths  Pneumonia and COVID-19 Deaths
# State
# Connecticut         130502.0                         4082.0
# Maine                61645.0                          872.0
# Massachusetts       240422.0                         8700.0
# New Hampshire        51581.0                         1155.0
# New Jersey          312963.0                        17287.0
# New York            667846.0                        31870.0
# Pennsylvania        557522.0                        22981.0
# Rhode Island         42462.0                         1764.0
# Vermont              23816.0                          321.0
# Illinois            446027.0                        19882.0
# Indiana             282262.0                        13954.0
# Iowa                125759.0                         4065.0
# Michigan            412252.0                        18475.0
# Minnesota           188637.0                         5610.0
# Missouri            273827.0                        11052.0
# Ohio                517794.0                        24089.0
# Wisconsin           223540.0                         6022.0
# Alabama             231602.0                         7411.0
# Arkansas            140174.0                         6060.0
# Delaware             41037.0                         1683.0
# Florida             915140.0                        50161.0
# Georgia             384074.0                        18689.0
# Kansas              112874.0                         4487.0
# Kentucky            209080.0                        10272.0
# Louisiana           199509.0                         8882.0
# Maryland            209247.0                         7256.0
# Mississippi         139919.0                         7469.0
# Nebraska             70422.0                         2493.0
# North Carolina      417304.0                        18048.0
# North Dakota         29913.0                         1621.0
# Oklahoma            171792.0                         8103.0
# South Carolina      224379.0                         8778.0
# South Dakota         34467.0                         1592.0
# Tennessee           330056.0                        15597.0
# Texas               931558.0                        58265.0
# Virginia            301033.0                         9805.0
# West Virginia        98692.0                         4281.0
# Alaska               20039.0                          813.0
# Arizona             284393.0                        17435.0
# California         1178346.0                        62152.0
# Colorado            176094.0                         7850.0
# Hawaii               47252.0                          977.0
# Idaho                63400.0                         2828.0
# Montana              44283.0                         1999.0
# Nevada              117594.0                         9210.0
# New Mexico           84955.0                         4876.0
# Oregon              158968.0                         3707.0
# Utah                 83772.0                         2808.0
# Washington          246807.0                         8830.0
# Wyoming              20597.0                          969.0
#
# [50 rows x 21 columns]

# %% [markdown]
# #### ALL

# %%
## bar chart of Total doses distributed vs Total doses administered by jurisdiction
ax = merge_all_df.plot(kind='bar', figsize=(10,8), x='State', y=['Total doses distributed', 'Total doses administered by jurisdiction'], 
                       rot=90, color=['blue', 'orange'])
plt.title("Total doses distributed vs Total doses administered by jurisdiction")
plt.tight_layout()

# %%
## bar chart of 2022 Population Estimate vs Total doses administered by jurisdiction
ax = merge_all_df.plot(kind='bar', figsize=(10,8), x='State', y=['2022 Population Estimate','Residents with at least one dose'], 
                                                                rot=90, color=['blue','red'])
plt.title("2022 Population Estimate vs Total doses administered by jurisdiction")
plt.tight_layout()

# %% [markdown]
# #### Analysis of chart above 2022 Population Estimate vs Total doses administered by jurisdiction
# #### 3 states have administered at least one more than the entire population
# #### In Dec. 2021, the CDC capped vaccination estimates to 95% to account for accuracy differences in vaccination coverage estimates between jurisdictions.
# #### https://usafacts.org/visualizations/covid-vaccine-tracker-states/state/connecticut/

# %% [markdown]
# #### Quartiles for all states

# %%
# Population - All states quartile calculations - 4 outliers (NY/CA/FL/TX)
all_pop = merge_all_df["2022 Population Estimate"] 
quartiles = all_pop.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of All states is: {lowerq}")
print(f"The upper quartile of All states is: {upperq}")
print(f"The interquartile range of All states is: {iqr}")
print(f"The the median of All states is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
outliers = all_pop[(all_pop>upper_bound) | (all_pop<lower_bound)]

if len(outliers) > 0:
    print(f"All states's potential outliers:{outliers}")
# Out:
# The lower quartile of All states is: 1946255.5
# The upper quartile of All states is: 7679138.75
# The interquartile range of All states is: 5732883.25
# The the median of All states is: 4551275.5
# Values below -6653069.375 could be outliers.
# Values above 16278463.625 could be outliers.
# All states's potential outliers:5     19677151
# 20    22244823
# 34    30029572
# 39    39029342
# Name: 2022 Population Estimate, dtype: int64

# %%
# Histogram of all states
merge_all_df['2022 Population Estimate'].plot(kind='hist', bins = 10, alpha=0.5, legend=True)
plt.title('2022 Population Estimate Per State')
plt.xlabel('2022 Population Estimate')
# plt.ylabel('2022 Population Estimate')
plt.show()

# %%
total_pop = merge_all_df["2022 Population Estimate"].sum()
total_pop
# Out:
# 332615754

# %%
#All states Variance and Standard deviation
# Demonstrate calculating the variance and standard deviation using the different modules
var_numpy = np.var(merge_all_df["2022 Population Estimate"],ddof = 0) # dof degrees of freedom
print(f"The population variance using the NumPy module is {var_numpy}")

sd_numpy = np.std(merge_all_df["2022 Population Estimate"],ddof = 0)
print(f"The population standard deviation using the NumPy module is {sd_numpy}")
# Out:
# The population variance using the NumPy module is 54407169506007.56
# The population standard deviation using the NumPy module is 7376121.576140646

# %% [markdown]
# ### Remove outlier states

# %%
# remove outliers (NY/CA/TX/FL) new df
ROL_to_all_df = merge_all_df.drop([5,20,34,39], axis=0)
ROL_to_all_df.head(50)
# Out:
#              State  2022 Population Estimate     Region  \
# 0      Connecticut                   3626205  Northeast
# 1            Maine                   1385340  Northeast
# 2    Massachusetts                   6981974  Northeast
# 3    New Hampshire                   1395231  Northeast
# 4       New Jersey                   9261699  Northeast
# 6     Pennsylvania                  12972008  Northeast
# 7     Rhode Island                   1093734  Northeast
# 8          Vermont                    647064  Northeast
# 9         Illinois                  12582032    Midwest
# 10         Indiana                   6833037    Midwest
# 11            Iowa                   3200517    Midwest
# 12        Michigan                  10034113    Midwest
# 13       Minnesota                   5717184    Midwest
# 14        Missouri                   6177957    Midwest
# 15            Ohio                  11756058    Midwest
# 16       Wisconsin                   5892539    Midwest
# 17         Alabama                   5074296      South
# 18        Arkansas                   3045637      South
# 19        Delaware                   1018396      South
# 21         Georgia                  10912876      South
# 22          Kansas                   2937150      South
# 23        Kentucky                   4512310      South
# 24       Louisiana                   4590241      South
# 25        Maryland                   6164660      South
# 26     Mississippi                   2940057      South
# 27        Nebraska                   1967923      South
# 28  North Carolina                  10698973      South
# 29    North Dakota                    779261      South
# 30        Oklahoma                   4019800      South
# 31  South Carolina                   5282634      South
# 32    South Dakota                    909824      South
# 33       Tennessee                   7051339      South
# 35        Virginia                   8683619      South
# 36   West Virginia                   1775156      South
# 37          Alaska                    733583       West
# 22                                         76.5
# 23                                         69.1
# 24                                         62.9
# 25                                         92.1
# 26                                         61.8
# 27                                         73.7
# 28                                         90.2
# 29                                         69.6
# 30                                         74.9
# 31                                         71.2
# 32                                         84.3
# 33                                         64.6
# 35                                         91.3
# 36                                         67.6
# 37                                         73.2
# 38                                         78.4
# 40                                         84.0
# 41                                         91.7
# 42                                         64.1
# 43                                         68.4
# 44                                         77.9
# 45                                         94.9
# 46                                         82.0
# 47                                         75.5
# 48                                         85.6
# 49                                         61.1
#
#     Residents 18+ with a completed primary series  \
# 0                                         2602449
# 1                                         1006201
# 2                                         5087207
# 3                                          891141
# 4                                         6195423
# 6                                         8447352
# 7                                          819194
# 8                                          467865
# 9                                         7874806
# 10                                        3511518
# 11                                        1818244
# 12                                        5615530
# 13                                        3533102
# 14                                        3276112
# 15                                        6367505
# 16                                        3539130
# 17                                        2416344
# 18                                        1547724
# 19                                         641112
# 21                                        5494615
# 22                                        1688660
# 23                                        2420948
# 24                                        2350247
# 25                                        4174362
# 26                                        1462932
# 27                                        1128474
# 28                                        6316324
# 29                                         403968
# 30                                        2173211
# 31                                        2811296
# 32                                         524003
# 33                                        3528315
# 35                                        5701220
# 36                                         989169
# 37                                         418608
# 38                                        4239941
# 40                                        3729317
# 41                                        1010380
# 42                                         909671
# 43                                         574244
# 44                                        1777961
# 45                                        1385236
# 46                                        2726093
# 47                                        1818842
# 48                                        5095049
# 49                                         281901
#
#     Residents 65+ with at least one dose  \
# 0                                 823664
# 1                                 366916
# 2                                1549552
# 3                                 304648
# 4                                1686625
# 6                                2919117
# 7                                 235273
# 8                                 151804
# 9                                2011136
# 10                               1046568
# 11                                564406
# 12                               1756102
# 13                                975356
# 14                               1058140
# 15                               1939194
# 16                               1081267
# 17                                840073
# 18                                524198
# 19                                225182
# 21                               1494072
# 22                                513572
# 23                                750781
# 24                                687335
# 25                               1057586
# 26                                457131
# 27                                318755
# 28                               2366178
# 29                                127584
# 30                                715240
# 31                                994994
# 32                                197409
# 33                               1082135
# 35                               1565047
# 36                                354072
# 37                                 90909
# 38                               1348446
# 40                                902546
# 41                                281382
# 42                                287593
# 43                                205131
# 44                                518532
# 45                                466822
# 46                                786172
# 47                                388400
# 48                               1298687
# 49                                 97375
#
#     Residents 65+ with a completed primary series  ...  \
# 0                                          654355  ...
# 1                                          303658  ...
# 2                                         1229041  ...
# 3                                          257396  ...
# 4                                         1439157  ...
# 6                                         2445124  ...
# 7                                          200777  ...
# 8                                          133976  ...
# 9                                         1865350  ...
# 10                                         976073  ...
# 11                                         532779  ...
# 12                                        1615024  ...
# 13                                         919278  ...
# 14                                         943084  ...
# 15                                        1834185  ...
# 16                                        1008957  ...
# 17                                         725159  ...
# 18                                         440981  ...
# 19                                         193640  ...
# 21                                        1315992  ...
# 22                                         462691  ...
# 23                                         671775  ...
# 24                                         647350  ...
# 25                                         954352  ...
# 26                                         419847  ...
# 27                                         297818  ...
# 28                                        1811611  ...
# 29                                         110011  ...
# 30                                         594390  ...
# 31                                         860836  ...
# 32                                         159605  ...
# 33                                         992506  ...
# 35                                        1329147  ...
# 36                                         321971  ...
# 37                                          81999  ...
# 38                                        1188267  ...
# 40                                         818078  ...
# 41                                         258069  ...
# 42                                         263280  ...
# 43                                         184619  ...
# 44                                         442765  ...
# 45                                         381631  ...
# 46                                         723687  ...
# 47                                         354415  ...
# 48                                        1188410  ...
# 49                                          87140  ...
#
#     Residents 5+ with at least one dose  \
# 0                               3640198
# 1                               1303033
# 2                               7306432
# 3                               1194903
# 4                               8374653
# 6                              11562144
# 7                               1117840
# 8                                614499
# 9                               9928857
# 10                              4321434
# 11                              2215662
# 12                              6921128
# 13                              4390824
# 14                              4236460
# 15                              7639577
# 16                              4341550
# 17                              3183544
# 18                              2104099
# 19                               856096
# 21                              7248684
# 22                              2209027
# 23                              3069983
# 24                              2915981
# 25                              5500247
# 26                              1835283
# 27                              1412159
# 28                              9392711
# 29                               524966
# 30                              2950731
# 31                              3646320
# 32                               739933
# 33                              4391102
# 35                              7712390
# 36                              1208323
# 37                               530318
# 38                              5663049
# 40                              4776300
# 41                              1285596
# 42                              1139488
# 43                               726052
# 44                              2392442
# 45                              1973116
# 46                              3420770
# 47                              2393586
# 48                              6428635
# 49                               352361
#
#     Residents 5+ with a completed primary series  Data As Of  Start Date  \
# 0                                        2948721  09/27/2023  01/01/2020
# 1                                        1116192  09/27/2023  01/01/2020
# 2                                        5770765  09/27/2023  01/01/2020
# 3                                         977652  09/27/2023  01/01/2020
# 4                                        7008596  09/27/2023  01/01/2020
# 6                                        9373738  09/27/2023  01/01/2020
# 7                                         926851  09/27/2023  01/01/2020
# 8                                         531036  09/27/2023  01/01/2020
# 9                                        8988132  09/27/2023  01/01/2020
# 10                                       3886503  09/27/2023  01/01/2020
# 11                                       2024863  09/27/2023  01/01/2020
# 12                                       6221234  09/27/2023  01/01/2020
# 13                                       4039371  09/27/2023  01/01/2020
# 14                                       3615520  09/27/2023  01/01/2020
# 15                                       7048249  09/27/2023  01/01/2020
# 16                                       3954892  09/27/2023  01/01/2020
# 17                                       2607644  09/27/2023  01/01/2020
# 18                                       1715538  09/27/2023  01/01/2020
# 19                                        713143  09/27/2023  01/01/2020
# 21                                       6085428  09/27/2023  01/01/2020
# 22                                       1898540  09/27/2023  01/01/2020
# 23                                       2661099  09/27/2023  01/01/2020
# 24                                       2558038  09/27/2023  01/01/2020
# 25                                       4794005  09/27/2023  01/01/2020
# 26                                       1598993  09/27/2023  01/01/2020
# 27                                       1278092  09/27/2023  01/01/2020
# 28                                       6987602  09/27/2023  01/01/2020
# 29                                        446460  09/27/2023  01/01/2020
# 30                                       2394480  09/27/2023  01/01/2020
# 31                                       3081834  09/27/2023  01/01/2020
# 32                                        586667  09/27/2023  01/01/2020
# 33                                       3843432  09/27/2023  01/01/2020
# 35                                       6507230  09/27/2023  01/01/2020
# 36                                       1069264  09/27/2023  01/01/2020
# 37                                        474707  09/27/2023  01/01/2020
# 38                                       4805903  09/27/2023  01/01/2020
# 40                                       4215139  09/27/2023  01/01/2020
# 45  09/23/2023  All Sexes  All Ages          8963.0      84955.0
# 46  09/23/2023  All Sexes  All Ages          9232.0     158968.0
# 47  09/23/2023  All Sexes  All Ages          5867.0      83772.0
# 48  09/23/2023  All Sexes  All Ages         15078.0     246807.0
# 49  09/23/2023  All Sexes  All Ages          1855.0      20597.0
#
#     Pneumonia and COVID-19 Deaths
# 0                          4082.0
# 1                           872.0
# 2                          8700.0
# 3                          1155.0
# 4                         17287.0
# 6                         22981.0
# 7                          1764.0
# 8                           321.0
# 9                         19882.0
# 10                        13954.0
# 11                         4065.0
# 12                        18475.0
# 13                         5610.0
# 14                        11052.0
# 15                        24089.0
# 16                         6022.0
# 17                         7411.0
# 18                         6060.0
# 19                         1683.0
# 21                        18689.0
# 22                         4487.0
# 23                        10272.0
# 24                         8882.0
# 25                         7256.0
# 26                         7469.0
# 27                         2493.0
# 28                        18048.0
# 29                         1621.0
# 30                         8103.0
# 31                         8778.0
# 32                         1592.0
# 33                        15597.0
# 35                         9805.0
# 36                         4281.0
# 37                          813.0
# 38                        17435.0
# 40                         7850.0
# 41                          977.0
# 42                         2828.0
# 43                         1999.0
# 44                         9210.0
# 45                         4876.0
# 46                         3707.0
# 47                         2808.0
# 48                         8830.0
# 49                          969.0
#
# [46 rows x 22 columns]

# %%
# check rows for outliers were removed
ROL_to_all_df.shape
# Out:
# (46, 22)

# %% [markdown]
# ### Histogram for remaining states

# %%
# removed outliers histogram
ROL_to_all_df['2022 Population Estimate'].plot(kind='hist', bins=8, alpha=0.5, legend=True)
plt.title('2022 Population Estimate Per State (outliers removed)')
plt.xlabel('2022 Population Estimate')
plt.show()

# %%
#All states Variance and Standard deviation - outliers removed
# Demonstrate calculating the variance and standard deviation using the different modules
var_numpy = np.var(ROL_to_all_df["2022 Population Estimate"],ddof = 0) # dof degrees of freedom
print(f"The population variance using the NumPy module is {var_numpy}")

sd_numpy = np.std(ROL_to_all_df["2022 Population Estimate"],ddof = 0)
print(f"The population standard deviation using the NumPy module is {sd_numpy}")
# Out:
# The population variance using the NumPy module is 12131875053153.146
# The population standard deviation using the NumPy module is 3483084.1294968957

# %% [markdown]
# ### Quartiles of remaining states (removed outliers)

# %%
# Population - removed outliers states quartile calculations NO outliers (no -> NY/CA/FL/TX)
ROL_pop = ROL_to_all_df["2022 Population Estimate"] 
quartiles = ROL_pop.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of ROL All states is: {lowerq}")
print(f"The upper quartile of ROL All states is: {upperq}")
print(f"The interquartile range of ROL All states is: {iqr}")
print(f"The the median of ROL All states is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
outliers = ROL_pop[(ROL_pop>upper_bound) | (ROL_pop<lower_bound)]

if len(outliers) > 0:
    print(f"ROL All states's potential outliers:{outliers}")
# Out:
# The lower quartile of ROL All states is: 1816125.25
# The upper quartile of ROL All states is: 6944739.75
# The interquartile range of ROL All states is: 5128614.5
# The the median of ROL All states is: 4129968.5
# Values below -5876796.5 could be outliers.
# Values above 14637661.5 could be outliers.

# %% [markdown]
# ### Outlier state new Dataframe - XL States

# %%
XL_state_rows = merge_all_df.loc[merge_all_df["2022 Population Estimate"] >= 19677151]
XL_state_rows
# Out:
#          State  2022 Population Estimate     Region  Total doses distributed  \
# 5     New York                  19677151  Northeast                 61302975
# 20     Florida                  22244823      South                 61526685
# 34       Texas                  30029572      South                 80813315
# 39  California                  39029342       West                121107865
#
#     Total doses administered by jurisdiction  \
# 5                                   45177512
# 20                                  42267369
# 34                                  52510128
# 39                                  88487852
#
#     Residents with at least one dose  \
# 5                           18427712
# 20                          17810446
# 34                          22322586
# 39                          33613401
#
#     Percent of total pop with at least one dose  \
# 5                                          94.7
# 20                                         82.9
# 34                                         77.0
# 39                                         85.1
#
#     Residents 18+ with a completed primary series  \
# 5                                        14013838
# 20                                       13732833
# 34                                       16008968
# 39                                       25681179
#
#     Residents 65+ with at least one dose  \
# 5                                3630599
# 20                               4944364
# 34                               3756924
# 39                               6058090
#
#     Residents 65+ with a completed primary series  ...  \
# 5                                         3195894  ...
# 20                                        4244393  ...
# 34                                        3330121  ...
# 39                                        5441414  ...
#
#     Residents 5+ with at least one dose  \
# 5                              18297040
# 20                             17757764
# 34                             22160914
# 39                             33267856
#
#     Residents 5+ with a completed primary series  Data As Of  Start Date  \
# 5                                       15686124  09/27/2023  01/01/2020
# 20                                      14946304  09/27/2023  01/01/2020
# 34                                      18363854  09/27/2023  01/01/2020
# 39                                      29371810  09/27/2023  01/01/2020
#
#       End Date        Sex Age Group COVID-19 Deaths Total Deaths  \
# 5   09/23/2023  All Sexes  All Ages         80440.0     667846.0
# 20  09/23/2023  All Sexes  All Ages         81894.0     915140.0
# 34  09/23/2023  All Sexes  All Ages        104421.0     931558.0
# 39  09/23/2023  All Sexes  All Ages        109248.0    1178346.0
#
#     Pneumonia and COVID-19 Deaths
# 5                         31870.0
# 20                        50161.0
# 34                        58265.0
# 39                        62152.0
#
# [4 rows x 22 columns]

# %%
#XL states variance and standard deviation
# Demonstrate calculating the variance and standard deviation using the different modules
var_numpy = np.var(XL_state_rows["2022 Population Estimate"],ddof = 0) # dof degrees of freedom
print(f"The population variance using the NumPy module is {var_numpy}")

sd_numpy = np.std(XL_state_rows["2022 Population Estimate"],ddof = 0)
print(f"The population standard deviation using the NumPy module is {sd_numpy}")
# Out:
# The population variance using the NumPy module is 56974444479285.5
# The population standard deviation using the NumPy module is 7548141.78982387

# %%
#write new csv file for XL states
XL_state_rows.to_csv("../data/1XL_state_rows.csv", index = False)

# %%
#Outlier states histogram
XL_state_rows['2022 Population Estimate'].plot(kind='hist', bins = 8, alpha=0.5, legend=True)
plt.title('2022 Population Estimate Per XL State')
plt.xlabel('2022 Population Estimate')
# plt.ylabel('2022 Population Estimate')
plt.show()

# %%
ax = XL_state_rows.plot(kind='bar', figsize=(10,4), x='State', y=['Total doses distributed', 
                                                                  'Total doses administered by jurisdiction',
                                                                 'Residents 65+ with a completed primary series', 
                                                                 'Residents 18+ with a completed primary series', 
                                                                 'Residents 12+ with a completed primary series', 
                                                                 'Residents 5+ with a completed primary series'], 
                                                                 rot=0, color=['black', 'orange', 'red','purple', 'pink', "gray"])
plt.title("Doses in Outlier States")
# plt.ylabel()
plt.tight_layout()

# %% [markdown]
# ### TOP 75% of USA population Dataframe [upper quartile] - outliers states excluded

# %%
#largest states only population < 19,677,151 & > 6944739 [threshold for upper quartile] TOP 75% of USA population -->>>(with XL removed)
large_st_rows = merge_all_df.loc[(merge_all_df["2022 Population Estimate"] < 19677151) & (merge_all_df["2022 Population Estimate"] > 6944739)]
large_st_rows
# Out:
#              State  2022 Population Estimate     Region  \
# 2    Massachusetts                   6981974  Northeast
# 4       New Jersey                   9261699  Northeast
# 6     Pennsylvania                  12972008  Northeast
# 9         Illinois                  12582032    Midwest
# 12        Michigan                  10034113    Midwest
# 15            Ohio                  11756058    Midwest
# 21         Georgia                  10912876      South
# 28  North Carolina                  10698973      South
# 33       Tennessee                   7051339      South
# 35        Virginia                   8683619      South
# 38         Arizona                   7359197       West
# 48      Washington                   7785786       West
#
#     Total doses distributed  Total doses administered by jurisdiction  \
# 2                  23747420                                  18179748
# 4                  29637655                                  19826065
# 6                  42895735                                  27586432
# 9                  38328915                                  26859342
# 12                 29638290                                  18769116
# 15                 31703485                                  21104771
# 21                 28727475                                  17124791
# 28                 30278310                                  19434544
# 33                 17172490                                  11323319
# 35                 26823665                                  19608172
# 38                 19959120                                  14647405
# 48                 25606455                                  17723480
#
#     Residents with at least one dose  \
# 2                            7393770
# 4                            8430561
# 6                           11666613
# 9                           10036899
# 12                           6979192
# 15                           7707458
# 21                           7287758
# 28                           9456334
# 33                           4413541
# 35                           7794449
# 38                           5704677
# 48                           6517326
#
#     Percent of total pop with at least one dose  \
# 2                                          95.0
# 4                                          94.9
# 6                                          91.1
# 9                                          79.2
# 12                                         69.9
# 15                                         65.9
# 21                                         68.6
# 28                                         90.2
# 33                                         64.6
# 35                                         91.3
# 38                                         78.4
# 48                                         85.6
#
#     Residents 18+ with a completed primary series  \
# 2                                         5087207
# 4                                         6195423
# 6                                         8447352
# 9                                         7874806
# 12                                        5615530
# 15                                        6367505
# 21                                        5494615
# 28                                        6316324
# 33                                        3528315
# 35                                        5701220
# 38                                        4239941
# 48                                        5095049
#
#     Residents 65+ with at least one dose  \
# 2                                1549552
# 4                                1686625
# 6                                2919117
# 9                                2011136
# 12                               1756102
# 15                               1939194
# 21                               1494072
# 28                               2366178
# 33                               1082135
# 35                               1565047
# 38                               1348446
# 48                               1298687
#
#     Residents 65+ with a completed primary series  ...  \
# 2                                         1229041  ...
# 4                                         1439157  ...
# 6                                         2445124  ...
# 9                                         1865350  ...
# 12                                        1615024  ...
# 15                                        1834185  ...
# 21                                        1315992  ...
# 28                                        1811611  ...
# 33                                         992506  ...
# 35                                        1329147  ...
# 38                                        1188267  ...
# 48                                        1188410  ...
#
#     Residents 5+ with at least one dose  \
# 2                               7306432
# 4                               8374653
# 6                              11562144
# 9                               9928857
# 12                              6921128
# 15                              7639577
# 21                              7248684
# 28                              9392711
# 33                              4391102
# 35                              7712390
# 38                              5663049
# 48                              6428635
#
#     Residents 5+ with a completed primary series  Data As Of  Start Date  \
# 2                                        5770765  09/27/2023  01/01/2020
# 4                                        7008596  09/27/2023  01/01/2020
# 6                                        9373738  09/27/2023  01/01/2020
# 9                                        8988132  09/27/2023  01/01/2020
# 12                                       6221234  09/27/2023  01/01/2020
# 15                                       7048249  09/27/2023  01/01/2020
# 21                                       6085428  09/27/2023  01/01/2020
# 28                                       6987602  09/27/2023  01/01/2020
# 33                                       3843432  09/27/2023  01/01/2020
# 35                                       6507230  09/27/2023  01/01/2020
# 38                                       4805903  09/27/2023  01/01/2020
# 48                                       5755895  09/27/2023  01/01/2020
#
#       End Date        Sex Age Group COVID-19 Deaths Total Deaths  \
# 2   09/23/2023  All Sexes  All Ages         21286.0     240422.0
# 4   09/23/2023  All Sexes  All Ages         35691.0     312963.0
# 6   09/23/2023  All Sexes  All Ages         53049.0     557522.0
# 9   09/23/2023  All Sexes  All Ages         38724.0     446027.0
# 12  09/23/2023  All Sexes  All Ages         37102.0     412252.0
# 15  09/23/2023  All Sexes  All Ages         49729.0     517794.0
# 21  09/23/2023  All Sexes  All Ages         36499.0     384074.0
# 28  09/23/2023  All Sexes  All Ages         34383.0     417304.0
# 33  09/23/2023  All Sexes  All Ages         30408.0     330056.0
# 35  09/23/2023  All Sexes  All Ages         23148.0     301033.0
# 38  09/23/2023  All Sexes  All Ages         30307.0     284393.0
# 48  09/23/2023  All Sexes  All Ages         15078.0     246807.0
#
#     Pneumonia and COVID-19 Deaths
# 2                          8700.0
# 4                         17287.0
# 6                         22981.0
# 9                         19882.0
# 12                        18475.0
# 15                        24089.0
# 21                        18689.0
# 28                        18048.0
# 33                        15597.0
# 35                         9805.0
# 38                        17435.0
# 48                         8830.0
#
# [12 rows x 22 columns]

# %%
large_st_rows["State"].unique()
# Out:
# array(['Massachusetts', 'New Jersey', 'Pennsylvania', 'Illinois',
#        'Michigan', 'Ohio', 'Georgia', 'North Carolina', 'Tennessee',
#        'Virginia', 'Arizona', 'Washington'], dtype=object)

# %%
#largest states variance and standard deviation
# Demonstrate calculating the variance and standard deviation using the different modules
var_numpy = np.var(large_st_rows["2022 Population Estimate"],ddof = 0) # dof degrees of freedom
print(f"The population variance using the NumPy module is {var_numpy}")

sd_numpy = np.std(large_st_rows["2022 Population Estimate"],ddof = 0)
print(f"The population standard deviation using the NumPy module is {sd_numpy}")
# Out:
# The population variance using the NumPy module is 4215283147536.139
# The population standard deviation using the NumPy module is 2053115.4735026814

# %%
# write new csv file for dataframe for Large states only
large_st_rows.to_csv("../data/1large_state_rows.csv", index = False)

# %%
#Large states histogram
large_st_rows['2022 Population Estimate'].plot(kind='hist', bins = 8, alpha=0.5, legend=True)
plt.title('2022 Population Estimate Per Large State')
plt.xlabel('2022 Population Estimate')
plt.show()

# %% [markdown]
# ### 50% of USA population Dataframe [interquartile] - outliers states excluded

# %%
#medium states only population < 6944739 & > 1816125 [interquartile]  50% of USA population -->>>(with XL removed)
medium_st_rows = merge_all_df.loc[(merge_all_df["2022 Population Estimate"] < 6944739) & (merge_all_df["2022 Population Estimate"] > 1816125)]
medium_st_rows
# Out:
#              State  2022 Population Estimate     Region  \
# 0      Connecticut                   3626205  Northeast
# 10         Indiana                   6833037    Midwest
# 11            Iowa                   3200517    Midwest
# 13       Minnesota                   5717184    Midwest
# 14        Missouri                   6177957    Midwest
# 16       Wisconsin                   5892539    Midwest
# 17         Alabama                   5074296      South
# 18        Arkansas                   3045637      South
# 22          Kansas                   2937150      South
# 23        Kentucky                   4512310      South
# 24       Louisiana                   4590241      South
# 25        Maryland                   6164660      South
# 26     Mississippi                   2940057      South
# 27        Nebraska                   1967923      South
# 30        Oklahoma                   4019800      South
# 31  South Carolina                   5282634      South
# 40        Colorado                   5839926       West
# 42           Idaho                   1939033       West
# 44          Nevada                   3177772       West
# 45      New Mexico                   2113344       West
# 46          Oregon                   4240137       West
# 47            Utah                   3380800       West
#
#     Total doses distributed  Total doses administered by jurisdiction  \
# 0                  11881825                                   9040989
# 10                 18989660                                  11201087
# 11                  9429185                                   6131087
# 13                 18519240                                  12829141
# 14                 15654225                                  10509024
# 16                 16474175                                  12444016
# 17                 12349530                                   7018011
# 18                  8373210                                   4874091
# 22                  8356725                                   5387922
# 23                 12200975                                   7510137
# 24                 10282120                                   6961453
# 25                 22359840                                  14722268
# 26                  7252325                                   4307637
# 27                  5481710                                   3822190
# 30                  9702330                                   6773461
# 31                 14205395                                   8666603
# 40                 17769135                                  13033446
# 42                  4751720                                   2894361
# 44                  7722770                                   5590682
# 45                  6176205                                   4750638
# 46                 14222125                                   9399175
# 47                  8421900                                   6158852
#
#     Residents with at least one dose  \
# 0                            3670090
# 10                           4350210
# 11                           2235485
# 13                           4461994
# 14                           4269469
# 16                           4386970
# 17                           3193141
# 18                           2115165
# 22                           2229631
# 23                           3086324
# 24                           2924163
# 25                           5566178
# 26                           1839306
# 27                           1425923
# 30                           2961991
# 31                           3666079
# 40                           4837792
# 42                           1146055
# 44                           2400362
# 45                           1989307
# 46                           3459096
# 47                           2421459
#
#     Percent of total pop with at least one dose  \
# 0                                          95.0
# 10                                         64.6
# 11                                         70.9
# 13                                         79.1
# 14                                         69.6
# 16                                         75.3
# 17                                         65.1
# 18                                         70.1
# 22                                         76.5
# 23                                         69.1
# 24                                         62.9
# 25                                         92.1
# 26                                         61.8
# 27                                         73.7
# 30                                         74.9
# 31                                         71.2
# 40                                         84.0
# 42                                         64.1
# 44                                         77.9
# 45                                         94.9
# 46                                         82.0
# 47                                         75.5
#
#     Residents 18+ with a completed primary series  \
# 0                                         2602449
# 10                                        3511518
# 11                                        1818244
# 13                                        3533102
# 14                                        3276112
# 16                                        3539130
# 17                                        2416344
# 18                                        1547724
# 22                                        1688660
# 23                                        2420948
# 24                                        2350247
# 25                                        4174362
# 26                                        1462932
# 27                                        1128474
# 30                                        2173211
# 31                                        2811296
# 40                                        3729317
# 42                                         909671
# 44                                        1777961
# 45                                        1385236
# 46                                        2726093
# 47                                        1818842
#
#     Residents 65+ with at least one dose  \
# 0                                 823664
# 10                               1046568
# 11                                564406
# 13                                975356
# 14                               1058140
# 16                               1081267
# 17                                840073
# 18                                524198
# 22                                513572
# 23                                750781
# 24                                687335
# 25                               1057586
# 26                                457131
# 27                                318755
# 30                                715240
# 31                                994994
# 40                                902546
# 42                                287593
# 44                                518532
# 45                                466822
# 46                                786172
# 47                                388400
#
#     Residents 65+ with a completed primary series  ...  \
# 0                                          654355  ...
# 10                                         976073  ...
# 11                                         532779  ...
# 13                                         919278  ...
# 14                                         943084  ...
# 16                                        1008957  ...
# 17                                         725159  ...
# 18                                         440981  ...
# 22                                         462691  ...
# 23                                         671775  ...
# 24                                         647350  ...
# 25                                         954352  ...
# 26                                         419847  ...
# 27                                         297818  ...
# 30                                         594390  ...
# 31                                         860836  ...
# 40                                         818078  ...
# 42                                         263280  ...
# 44                                         442765  ...
# 45                                         381631  ...
# 46                                         723687  ...
# 47                                         354415  ...
#
#     Residents 5+ with at least one dose  \
# 0                               3640198
# 10                              4321434
# 11                              2215662
# 13                              4390824
# 14                              4236460
# 16                              4341550
# 17                              3183544
# 18                              2104099
# 22                              2209027
# 23                              3069983
# 24                              2915981
# 25                              5500247
# 26                              1835283
# 27                              1412159
# 30                              2950731
# 31                              3646320
# 40                              4776300
# 42                              1139488
# 44                              2392442
# 45                              1973116
# 46                              3420770
# 47                              2393586
#
#     Residents 5+ with a completed primary series  Data As Of  Start Date  \
# 0                                        2948721  09/27/2023  01/01/2020
# 10                                       3886503  09/27/2023  01/01/2020
# 11                                       2024863  09/27/2023  01/01/2020
# 13                                       4039371  09/27/2023  01/01/2020
# 14                                       3615520  09/27/2023  01/01/2020
# 16                                       3954892  09/27/2023  01/01/2020
# 17                                       2607644  09/27/2023  01/01/2020
# 18                                       1715538  09/27/2023  01/01/2020
# 22                                       1898540  09/27/2023  01/01/2020
# 23                                       2661099  09/27/2023  01/01/2020
# 24                                       2558038  09/27/2023  01/01/2020
# 25                                       4794005  09/27/2023  01/01/2020
# 26                                       1598993  09/27/2023  01/01/2020
# 27                                       1278092  09/27/2023  01/01/2020
# 30                                       2394480  09/27/2023  01/01/2020
# 31                                       3081834  09/27/2023  01/01/2020
# 40                                       4215139  09/27/2023  01/01/2020
# 42                                       1008843  09/27/2023  01/01/2020
# 44                                       1962621  09/27/2023  01/01/2020
# 45                                       1575380  09/27/2023  01/01/2020
# 46                                       3048791  09/27/2023  01/01/2020
# 47                                       2134792  09/27/2023  01/01/2020
#
#       End Date        Sex Age Group COVID-19 Deaths Total Deaths  \
# 0   09/23/2023  All Sexes  All Ages         12571.0     130502.0
# 10  09/23/2023  All Sexes  All Ages         26885.0     282262.0
# 11  09/23/2023  All Sexes  All Ages         11026.0     125759.0
# 13  09/23/2023  All Sexes  All Ages         15298.0     188637.0
# 14  09/23/2023  All Sexes  All Ages         23363.0     273827.0
# 16  09/23/2023  All Sexes  All Ages         17064.0     223540.0
# 17  09/23/2023  All Sexes  All Ages         21520.0     231602.0
# 18  09/23/2023  All Sexes  All Ages         12663.0     140174.0
# 22  09/23/2023  All Sexes  All Ages         10152.0     112874.0
# 23  09/23/2023  All Sexes  All Ages         20274.0     209080.0
# 24  09/23/2023  All Sexes  All Ages         17722.0     199509.0
# 25  09/23/2023  All Sexes  All Ages         18143.0     209247.0
# 26  09/23/2023  All Sexes  All Ages         14955.0     139919.0
# 27  09/23/2023  All Sexes  All Ages          5815.0      70422.0
# 30  09/23/2023  All Sexes  All Ages         18520.0     171792.0
# 31  09/23/2023  All Sexes  All Ages         20842.0     224379.0
# 40  09/23/2023  All Sexes  All Ages         15378.0     176094.0
# 42  09/23/2023  All Sexes  All Ages          5610.0      63400.0
# 44  09/23/2023  All Sexes  All Ages         12259.0     117594.0
# 45  09/23/2023  All Sexes  All Ages          8963.0      84955.0
# 46  09/23/2023  All Sexes  All Ages          9232.0     158968.0
# 47  09/23/2023  All Sexes  All Ages          5867.0      83772.0
#
#     Pneumonia and COVID-19 Deaths
# 0                          4082.0
# 10                        13954.0
# 11                         4065.0
# 13                         5610.0
# 14                        11052.0
# 16                         6022.0
# 17                         7411.0
# 18                         6060.0
# 22                         4487.0
# 23                        10272.0
# 24                         8882.0
# 25                         7256.0
# 26                         7469.0
# 27                         2493.0
# 30                         8103.0
# 31                         8778.0
# 40                         7850.0
# 42                         2828.0
# 44                         9210.0
# 45                         4876.0
# 46                         3707.0
# 47                         2808.0
#
# [22 rows x 22 columns]

# %%
medium_st_rows["State"].unique()
# Out:
# array(['Connecticut', 'Indiana', 'Iowa', 'Minnesota', 'Missouri',
#        'Wisconsin', 'Alabama', 'Arkansas', 'Kansas', 'Kentucky',
#        'Louisiana', 'Maryland', 'Mississippi', 'Nebraska', 'Oklahoma',
#        'South Carolina', 'Colorado', 'Idaho', 'Nevada', 'New Mexico',
#        'Oregon', 'Utah'], dtype=object)

# %%
# new medium state dataframe to csv file
medium_st_rows.to_csv("../data/1medium_state_rows.csv", index = False)

# %%
#medium states histogram
medium_st_rows['2022 Population Estimate'].plot(kind='hist', bins=8, alpha=0.5, legend=True)
plt.title('2022 Population Estimate Per Medium State')
plt.xlabel('2022 Population Estimate')
plt.show()

# %%
#medium states variance and standard deviation
# Demonstrate calculating the variance and standard deviation using the different modules
var_numpy = np.var(medium_st_rows["2022 Population Estimate"],ddof = 0) # dof degrees of freedom
print(f"The population variance using the NumPy module is {var_numpy}")

sd_numpy = np.std(medium_st_rows["2022 Population Estimate"],ddof = 0)
print(f"The population standard deviation using the NumPy module is {sd_numpy}")
# Out:
# The population variance using the NumPy module is 2126604782650.217
# The population standard deviation using the NumPy module is 1458288.3057373178

# %% [markdown]
# ### Lower 25% of USA population Dataframe [Lower quartile] - outliers states excluded

# %%
#small states only population < 1816125 [lower quartile]  lower 25% of USA population -->>>(with XL removed)
small_st_rows = merge_all_df.loc[merge_all_df["2022 Population Estimate"] < 1816125]
small_st_rows
# Out:
#             State  2022 Population Estimate     Region  \
# 1           Maine                   1385340  Northeast
# 3   New Hampshire                   1395231  Northeast
# 7    Rhode Island                   1093734  Northeast
# 8         Vermont                    647064  Northeast
# 19       Delaware                   1018396      South
# 29   North Dakota                    779261      South
# 32   South Dakota                    909824      South
# 36  West Virginia                   1775156      South
# 37         Alaska                    733583       West
# 41         Hawaii                   1440196       West
# 43        Montana                   1122867       West
# 49        Wyoming                    581381       West
#
#     Total doses distributed  Total doses administered by jurisdiction  \
# 1                   4981040                                   3542346
# 3                   5121800                                   2983122
# 7                   3531485                                   2672092
# 8                   2588940                                   1762563
# 19                  3352025                                   2169125
# 29                  1910860                                   1314469
# 32                  2713025                                   1688981
# 36                  5515855                                   3098571
# 37                  2176065                                   1328221
# 41                  4677910                                   3530357
# 43                  2714785                                   1870288
# 49                  1281755                                    854132
#
#     Residents with at least one dose  \
# 1                            1315892
# 3                            1203845
# 7                            1126779
# 8                             623937
# 19                            861811
# 29                            530640
# 32                            746118
# 36                           1212338
# 37                            535718
# 41                           1297884
# 43                            731323
# 49                            353727
#
#     Percent of total pop with at least one dose  \
# 1                                          95.0
# 3                                          88.5
# 7                                          95.0
# 8                                          95.0
# 19                                         88.5
# 29                                         69.6
# 32                                         84.3
# 36                                         67.6
# 37                                         73.2
# 41                                         91.7
# 43                                         68.4
# 49                                         61.1
#
#     Residents 18+ with a completed primary series  \
# 1                                         1006201
# 3                                          891141
# 7                                          819194
# 8                                          467865
# 19                                         641112
# 29                                         403968
# 32                                         524003
# 36                                         989169
# 37                                         418608
# 41                                        1010380
# 43                                         574244
# 49                                         281901
#
#     Residents 65+ with at least one dose  \
# 1                                 366916
# 3                                 304648
# 7                                 235273
# 8                                 151804
# 19                                225182
# 29                                127584
# 32                                197409
# 36                                354072
# 37                                 90909
# 41                                281382
# 43                                205131
# 49                                 97375
#
#     Residents 65+ with a completed primary series  ...  \
# 1                                          303658  ...
# 3                                          257396  ...
# 7                                          200777  ...
# 8                                          133976  ...
# 19                                         193640  ...
# 29                                         110011  ...
# 32                                         159605  ...
# 36                                         321971  ...
# 37                                          81999  ...
# 41                                         258069  ...
# 43                                         184619  ...
# 49                                          87140  ...
#
#     Residents 5+ with at least one dose  \
# 1                               1303033
# 3                               1194903
# 7                               1117840
# 8                                614499
# 19                               856096
# 29                               524966
# 32                               739933
# 36                              1208323
# 37                               530318
# 41                              1285596
# 43                               726052
# 49                               352361
#
#     Residents 5+ with a completed primary series  Data As Of  Start Date  \
# 1                                        1116192  09/27/2023  01/01/2020
# 3                                         977652  09/27/2023  01/01/2020
# 7                                         926851  09/27/2023  01/01/2020
# 8                                         531036  09/27/2023  01/01/2020
# 19                                        713143  09/27/2023  01/01/2020
# 29                                        446460  09/27/2023  01/01/2020
# 32                                        586667  09/27/2023  01/01/2020
# 36                                       1069264  09/27/2023  01/01/2020
# 37                                        474707  09/27/2023  01/01/2020
# 41                                       1150133  09/27/2023  01/01/2020
# 43                                        631474  09/27/2023  01/01/2020
# 49                                        306932  09/27/2023  01/01/2020
#
#       End Date        Sex Age Group COVID-19 Deaths Total Deaths  \
# 1   09/23/2023  All Sexes  All Ages          3235.0      61645.0
# 3   09/23/2023  All Sexes  All Ages          3112.0      51581.0
# 7   09/23/2023  All Sexes  All Ages          4083.0      42462.0
# 8   09/23/2023  All Sexes  All Ages           976.0      23816.0
# 19  09/23/2023  All Sexes  All Ages          3445.0      41037.0
# 29  09/23/2023  All Sexes  All Ages          3101.0      29913.0
# 32  09/23/2023  All Sexes  All Ages          3472.0      34467.0
# 36  09/23/2023  All Sexes  All Ages          8339.0      98692.0
# 37  09/23/2023  All Sexes  All Ages          1492.0      20039.0
# 41  09/23/2023  All Sexes  All Ages          1943.0      47252.0
# 43  09/23/2023  All Sexes  All Ages          3961.0      44283.0
# 49  09/23/2023  All Sexes  All Ages          1855.0      20597.0
#
#     Pneumonia and COVID-19 Deaths
# 1                           872.0
# 3                          1155.0
# 7                          1764.0
# 8                           321.0
# 19                         1683.0
# 29                         1621.0
# 32                         1592.0
# 36                         4281.0
# 37                          813.0
# 41                          977.0
# 43                         1999.0
# 49                          969.0
#
# [12 rows x 22 columns]

# %%
small_st_rows["State"].unique()
# Out:
# array(['Maine', 'New Hampshire', 'Rhode Island', 'Vermont', 'Delaware',
#        'North Dakota', 'South Dakota', 'West Virginia', 'Alaska',
#        'Hawaii', 'Montana', 'Wyoming'], dtype=object)

# %%
small_st_rows.to_csv("../data/1small_state_rows.csv", index = False)

# %%
#small states histogram
small_st_rows['2022 Population Estimate'].plot(kind='hist', bins=7, alpha=0.5, legend=True)
plt.title('2022 Population Estimate Per Small State')
plt.xlabel('2022 Population Estimate')
plt.show()

# %%
#small states variance and standard deviation
# Demonstrate calculating the variance and standard deviation using the different modules
var_numpy = np.var(small_st_rows["2022 Population Estimate"],ddof = 0) # dof degrees of freedom
print(f"The population variance using the NumPy module is {var_numpy}")

sd_numpy = np.std(small_st_rows["2022 Population Estimate"],ddof = 0)
print(f"The population standard deviation using the NumPy module is {sd_numpy}")
# Out:
# The population variance using the NumPy module is 123863654010.52083
# The population standard deviation using the NumPy module is 351942.6856897595

# %% [markdown]
# ### Calculate % US population per new grouping

# %%
XL_total_pop = XL_state_rows["2022 Population Estimate"].sum()
Large_total_pop = large_st_rows["2022 Population Estimate"].sum()
Medium_total_pop = medium_st_rows["2022 Population Estimate"].sum()
Small_total_pop = small_st_rows["2022 Population Estimate"].sum()

# %%
per_XL_pop = (XL_total_pop/total_pop)*100
format_per_XL = format(per_XL_pop, '.0f')
print(f"Outlier states total population is {format_per_XL}% of the United States total population")

per_L_pop = (Large_total_pop/total_pop)*100
format_per_L = format(per_L_pop, '.0f')
print(f"Large states total population is {format_per_L}% of the United States total population")

per_M_pop = (Medium_total_pop/total_pop)*100
format_per_M = format(per_M_pop, '.0f')
print(f"Medium states total population is {format_per_M}% of the United States total population")

per_S_pop = (Small_total_pop/total_pop)*100
format_per_S = format(per_S_pop, '.0f')
print(f"Small states total population is {format_per_S}% of the United States total population")
# Out:
# Outlier states total population is 33% of the United States total population
# Large states total population is 35% of the United States total population
# Medium states total population is 28% of the United States total population
# Small states total population is 4% of the United States total population

# %% [markdown]
# ### Pie charts of small states Total doses distributed' vs 'Total doses administered by jurisdiction'

# %%
# transpose df small
small_137= pd.DataFrame({'Total doses distributed':[4981040,5121800,3531485],
                    'Total doses administered by jurisdiction':[3542346,2983122,2672092]},
                    index=['Maine','New Hampshire','Rhode Island'])
# Small state pie charts
small_137_pie= small_137.T.plot.pie(subplots=True,autopct='%1.1f%%',figsize=(30,15),shadow=True,)

# %%
# transpose df small
small_8_19_29= pd.DataFrame({'Total doses distributed':[2588940,3352025,1910860],
                    'Total doses administered by jurisdiction':[1762563,2169125,1314469]},
                    index=['Vermont','Delaware','North Dakota'])
# Small state pie charts
small_8_19_29_pie= small_8_19_29.T.plot.pie(subplots=True,autopct='%1.1f%%',figsize=(30,15),shadow=True,)

# %%
maine_pie3 = small_st_rows[['Total doses distributed', 'Total doses administered by jurisdiction']]
smallpie3filteredrow_df = maine_pie3.iloc[0]
smallpie3filteredrow_df.T.plot.pie(subplots=True, legend = True, figsize=(30,15), autopct='%1.1f%%')
# Out:
# array([<Axes: ylabel='1'>], dtype=object)

# %%
# checking rows
small_pie3 = small_st_rows[['Total doses distributed', 'Total doses administered by jurisdiction']]
smallpie3filteredrow_df = small_pie3.iloc[6:9]
smallpie3filteredrow_df.T.plot.pie(subplots=True, figsize=(30,15), autopct='%1.1f%%')
# Out:
# array([<Axes: ylabel='32'>, <Axes: ylabel='36'>, <Axes: ylabel='37'>],
#       dtype=object)

# %%
#checking rows
small_pie3 = small_st_rows[['Total doses distributed', 'Total doses administered by jurisdiction']]
smallpie3filteredrow_df = small_pie3.iloc[9:13]
smallpie3filteredrow_df.T.plot.pie(subplots=True, figsize=(30,15), autopct='%1.1f%%')
# Out:
# array([<Axes: ylabel='41'>, <Axes: ylabel='43'>, <Axes: ylabel='49'>],
#       dtype=object)

# %% [markdown]
# ### Linear regression

# %%
# Plot out Percent of total pop with at least one dose vs COVID-19 Deaths
x_values = merge_all_df['Percent of total pop with at least one dose']
y_values = merge_all_df['COVID-19 Deaths']
plt.scatter(x_values,y_values)
plt.xlabel('Percent of total pop with at least one dose')
plt.ylabel('COVID-19 Deaths')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(65,80000),fontsize=15,color="red")
plt.title("Percent of total population with at least one dose vs COVID-19 Deaths")

print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.006604845243760462

# %%
# Plot out Percent of total pop with at least one dose vs COVID-19 Deaths
x_values = merge_all_df['Percent of total pop with at least one dose']
y_values = merge_all_df['Total Deaths']
plt.scatter(x_values,y_values)
plt.xlabel('Percent of total pop with at least one dose')
plt.ylabel('Total Deaths')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(65,80000),fontsize=15,color="black")
plt.title("Percent of total population with at least one dose vs Total Deaths")

print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.006929896302602268

# %% [markdown]
# #### T-tests - Hypothesis testing - All states - Population vs COVID-19 Deaths

# %%
# total us states
def gendata(loc1=0, loc2=0):
    population1 = merge_all_df["2022 Population Estimate"]
    population2 = merge_all_df["COVID-19 Deaths"]

    # Scatter Plot of Data
    plt.subplot(2, 1, 1)
    plt.scatter(range(len(population1)), population1, label="population1")
    plt.scatter(range(len(population2)), population2, label="population2")
    plt.legend()

    # Histogram Plot of Data
    plt.subplot(2, 1, 2)
    plt.hist(population1, 10, density=True, alpha=0.7, label="population1")
    plt.hist(population2, 10, density=True, alpha=0.7, label="population2")
    plt.axvline(population1.mean(), color='k', linestyle='dashed', linewidth=1)
    plt.axvline(population2.mean(), color='k', linestyle='dashed', linewidth=1)
    plt.legend()  
    
    return population1, population2

# %%
# Generate some data and show the scatter plot # total us states
population1, population2 = gendata()

# %%
# Note: Setting equal_var=False performs Welch's t-test which does 
# not assume equal population variance
# total us states
stats.ttest_ind(population1, population2, equal_var=False)
# Out:
# TtestResult(statistic=6.2913428026692815, pvalue=8.30782269361282e-08, df=49.001098778771855)

# %% [markdown]
# #### T-tests - Hypothesis testing - Outlier states - Population vs COVID-19 Deaths

# %%
# XL us states
def gendata(loc1=0, loc2=0):
    population1 = XL_state_rows["2022 Population Estimate"]
    population2 = XL_state_rows["COVID-19 Deaths"]

    # Scatter Plot of Data
    plt.subplot(2, 1, 1)
    plt.scatter(range(len(population1)), population1, label="population1")
    plt.scatter(range(len(population2)), population2, label="population2")
    plt.legend()

    # Histogram Plot of Data
    plt.subplot(2, 1, 2)
    plt.hist(population1, 10, density=True, alpha=0.7, label="population1")
    plt.hist(population2, 10, density=True, alpha=0.7, label="population2")
    plt.axvline(population1.mean(), color='k', linestyle='dashed', linewidth=1)
    plt.axvline(population2.mean(), color='k', linestyle='dashed', linewidth=1)
    plt.legend()  
    
    return population1, population2

# %%
# Generate some data and show the scatter plot # total us states
population1, population2 = gendata()

# %%
# Note: Setting equal_var=False performs Welch's t-test which does 
# not assume equal population variance
# total us states
stats.ttest_ind(population1, population2, equal_var=False)
# Out:
# TtestResult(statistic=6.345038403942637, pvalue=0.007918219633692948, df=3.0000176797049503)

# %% [markdown]
# #### T-tests - Hypothesis testing - Top 75% states - Population vs COVID-19 Deaths

# %%
# Large us states
def gendata(loc1=0, loc2=0):
    population1 = large_st_rows["2022 Population Estimate"]
    population2 = large_st_rows["COVID-19 Deaths"]

    # Scatter Plot of Data
    plt.subplot(2, 1, 1)
    plt.scatter(range(len(population1)), population1, label="population1")
    plt.scatter(range(len(population2)), population2, label="population2")
    plt.legend()

    # Histogram Plot of Data
    plt.subplot(2, 1, 2)
    plt.hist(population1, 10, density=True, alpha=0.7, label="population1")
    plt.hist(population2, 10, density=True, alpha=0.7, label="population2")
    plt.axvline(population1.mean(), color='k', linestyle='dashed', linewidth=1)
    plt.axvline(population2.mean(), color='k', linestyle='dashed', linewidth=1)
    plt.legend()  
    
    return population1, population2

# %%
# Generate some data and show the scatter plot # total us states
population1, population2 = gendata()

# %%
# Note: Setting equal_var=False performs Welch's t-test which does 
# not assume equal population variance
# total us states
stats.ttest_ind(population1, population2, equal_var=False)
# Out:
# TtestResult(statistic=15.571585807521892, pvalue=7.678184897918796e-09, df=11.000571878284301)

# %% [markdown]
# #### T-tests - Hypothesis testing - 50% states - Population vs COVID-19 Deaths

# %%
# medium us states
def gendata(loc1=0, loc2=0):
    population1 = medium_st_rows["2022 Population Estimate"]
    population2 = medium_st_rows["COVID-19 Deaths"]

    # Scatter Plot of Data
    plt.subplot(2, 1, 1)
    plt.scatter(range(len(population1)), population1, label="population1")
    plt.scatter(range(len(population2)), population2, label="population2")
    plt.legend()

    # Histogram Plot of Data
    plt.subplot(2, 1, 2)
    plt.hist(population1, 10, density=True, alpha=0.7, label="population1")
    plt.hist(population2, 10, density=True, alpha=0.7, label="population2")
    plt.axvline(population1.mean(), color='k', linestyle='dashed', linewidth=1)
    plt.axvline(population2.mean(), color='k', linestyle='dashed', linewidth=1)
    plt.legend()  
    
    return population1, population2

# %%
# Generate some data and show the scatter plot # total us states
population1, population2 = gendata()

# %%
# Note: Setting equal_var=False performs Welch's t-test which does 
# not assume equal population variance
# total us states
stats.ttest_ind(population1, population2, equal_var=False)
# Out:
# TtestResult(statistic=13.190842858104798, pvalue=1.2471943632101552e-11, df=21.000657203524447)

# %% [markdown]
# #### T-tests - Hypothesis testing - Lower 25% states - Population vs COVID-19 Deaths

# %%
# small us states
def gendata(loc1=0, loc2=0):
    population1 = small_st_rows["2022 Population Estimate"]
    population2 = small_st_rows["COVID-19 Deaths"]

    # Scatter Plot of Data
    plt.subplot(2, 1, 1)
    plt.scatter(range(len(population1)), population1, label="population1")
    plt.scatter(range(len(population2)), population2, label="population2")
    plt.legend()

    # Histogram Plot of Data
    plt.subplot(2, 1, 2)
    plt.hist(population1, 10, density=True, alpha=0.7, label="population1")
    plt.hist(population2, 10, density=True, alpha=0.7, label="population2")
    plt.axvline(population1.mean(), color='k', linestyle='dashed', linewidth=1)
    plt.axvline(population2.mean(), color='k', linestyle='dashed', linewidth=1)
    plt.legend()  
    
    return population1, population2

# %%
# Generate some data and show the scatter plot # total us states
population1, population2 = gendata()

# %%
# Note: Setting equal_var=False performs Welch's t-test which does 
# not assume equal population variance
# total us states
stats.ttest_ind(population1, population2, equal_var=False)
# Out:
# TtestResult(statistic=10.085665480331793, pvalue=6.785537424044183e-07, df=11.000579349510655)

# %% [markdown]
# #### T-tests - Hypothesis testing - All states - Residents with at least one dose vs COVID-19 Deaths

# %%
# total us states
def gendata(loc1=0, loc2=0):
    population1 = merge_all_df["Residents with at least one dose"]
    population2 = merge_all_df["COVID-19 Deaths"]

    # Scatter Plot of Data
    plt.subplot(2, 1, 1)
    plt.scatter(range(len(population1)), population1, label="population1")
    plt.scatter(range(len(population2)), population2, label="population2")
    plt.legend()

    # Histogram Plot of Data
    plt.subplot(2, 1, 2)
    plt.hist(population1, 10, density=True, alpha=0.7, label="population1")
    plt.hist(population2, 10, density=True, alpha=0.7, label="population2")
    plt.axvline(population1.mean(), color='k', linestyle='dashed', linewidth=1)
    plt.axvline(population2.mean(), color='k', linestyle='dashed', linewidth=1)
    plt.legend()  
    
    return population1, population2

# %%
# Generate some data and show the scatter plot # total us states
population1, population2 = gendata()

# %%
# Run the t-test on the two population samples. # total us states
stats.ttest_ind(population1, population2, equal_var=False)
# Out:
# TtestResult(statistic=5.9776418070751856, pvalue=2.5332866530616385e-07, df=49.00156857304736)

# %% [markdown]
# #### T-tests - Hypothesis testing - Outlier states - Residents with at least one dose vs COVID-19 Deaths

# %%
# XL states
def gendata(loc1=0, loc2=0):
    population1 = XL_state_rows["Residents with at least one dose"]
    population2 = XL_state_rows["COVID-19 Deaths"]

    # Scatter Plot of Data
    plt.subplot(2, 1, 1)
    plt.scatter(range(len(population1)), population1, label="population1")
    plt.scatter(range(len(population2)), population2, label="population2")
    plt.legend()

    # Histogram Plot of Data
    plt.subplot(2, 1, 2)
    plt.hist(population1, 10, density=True, alpha=0.7, label="population1")
    plt.hist(population2, 10, density=True, alpha=0.7, label="population2")
    plt.axvline(population1.mean(), color='k', linestyle='dashed', linewidth=1)
    plt.axvline(population2.mean(), color='k', linestyle='dashed', linewidth=1)
    plt.legend()  
    
    return population1, population2

# %%
# Generate some data and show the scatter plot # XL states
population1, population2 = gendata()

# %%
# Run the t-test on the two population samples. # XL states
stats.ttest_ind(population1, population2, equal_var=False)
# Out:
# TtestResult(statistic=6.26673353859866, pvalue=0.008201470297977072, df=3.0000250363104377)

# %% [markdown]
# #### T-tests - Hypothesis testing - Top 75% states - Residents with at least one dose vs COVID-19 Deaths

# %%
# large states
def gendata(loc1=0, loc2=0):
    population1 = large_st_rows["Residents with at least one dose"]
    population2 = large_st_rows["COVID-19 Deaths"]

    # Scatter Plot of Data
    plt.subplot(2, 1, 1)
    plt.scatter(range(len(population1)), population1, label="population1")
    plt.scatter(range(len(population2)), population2, label="population2")
    plt.legend()

    # Histogram Plot of Data
    plt.subplot(2, 1, 2)
    plt.hist(population1, 10, density=True, alpha=0.7, label="population1")
    plt.hist(population2, 10, density=True, alpha=0.7, label="population2")
    plt.axvline(population1.mean(), color='k', linestyle='dashed', linewidth=1)
    plt.axvline(population2.mean(), color='k', linestyle='dashed', linewidth=1)
    plt.legend()  
    
    return population1, population2

# %%
# Generate some data and show the scatter plot # large states
population1, population2 = gendata()

# %%
# Run the t-test on the two population samples. # large states
stats.ttest_ind(population1, population2, equal_var=False)
# Out:
# TtestResult(statistic=13.785041911645616, pvalue=2.761460556534477e-08, df=11.000693619517259)

# %% [markdown]
# #### T-tests - Hypothesis testing - 50% states - Residents with at least one dose vs COVID-19 Deaths

# %%
# medium states t-testing
def gendata(loc1=0, loc2=0):
    population1 = medium_st_rows["Residents with at least one dose"]
    population2 = medium_st_rows["COVID-19 Deaths"]

    # Scatter Plot of Data
    plt.subplot(2, 1, 1)
    plt.scatter(range(len(population1)), population1, label="population1")
    plt.scatter(range(len(population2)), population2, label="population2")
    plt.legend()

    # Histogram Plot of Data
    plt.subplot(2, 1, 2)
    plt.hist(population1, 10, density=True, alpha=0.7, label="population1")
    plt.hist(population2, 10, density=True, alpha=0.7, label="population2")
    plt.axvline(population1.mean(), color='k', linestyle='dashed', linewidth=1)
    plt.axvline(population2.mean(), color='k', linestyle='dashed', linewidth=1)
    plt.legend()  
    
    return population1, population2

# %%
# Generate some data and show the scatter plot # medium states
population1, population2 = gendata()

# %%
# Run the t-test on the two population samples. # medium states
stats.ttest_ind(population1, population2, equal_var=False)
# Out:
# TtestResult(statistic=12.343154031556054, pvalue=4.3187172973947105e-11, df=21.001051673771578)

# %% [markdown]
# #### T-tests - Hypothesis testing - Lower 25% states - Residents with at least one dose vs COVID-19 Deaths

# %%
# small states t-testing
def gendata(loc1=0, loc2=0):
    population1 = small_st_rows["Residents with at least one dose"]
    population2 = small_st_rows["COVID-19 Deaths"]

    # Scatter Plot of Data
    plt.subplot(2, 1, 1)
    plt.scatter(range(len(population1)), population1, label="population1")
    plt.scatter(range(len(population2)), population2, label="population2")
    plt.legend()

    # Histogram Plot of Data
    plt.subplot(2, 1, 2)
    plt.hist(population1, 10, density=True, alpha=0.7, label="population1")
    plt.hist(population2, 10, density=True, alpha=0.7, label="population2")
    plt.axvline(population1.mean(), color='k', linestyle='dashed', linewidth=1)
    plt.axvline(population2.mean(), color='k', linestyle='dashed', linewidth=1)
    plt.legend()  
    
    return population1, population2

# %%
# Generate some data and show the scatter plot # small states
population1, population2 = gendata()

# %%
# Run the t-test on the two population samples. # small states
stats.ttest_ind(population1, population2, equal_var=False)
# Out:
# TtestResult(statistic=8.941401273132938, pvalue=2.233407020080434e-06, df=11.000681110858586)
